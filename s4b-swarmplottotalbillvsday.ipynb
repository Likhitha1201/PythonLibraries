# %%
""" 

    @Author: Likhitha S
    @Date: 25-10-2024 15:30
    @Last Modified by: Likhitha S
    @Last Modified time: 25-10-2024 15:30
    @Title: Write a program to draw swarm plot of “total bill” against day for a dataset given in url 
    https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv 


"""


import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

def main():
    """

        Description: 
            This function is used to draw a graph using box plot.
        Parameters: 
            url is the input where we are going to get the dataset.
        return:
            It displays the graph with swarmplot.

    """
    
    
    url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
    var= pd.read_csv(url)
    
    print(var)
    
    plt.figure(figsize=(10,5))
    sns.swarmplot(x='day', y='total_bill', data=var)
    
    plt.title("Total Bill V/S Day's")
    plt.xlabel("day's")
    plt.ylabel('totalbill')
    
    plt.show()
    
if __name__=="__main__":
    main()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# c:\Users\Likhitha S\OneDrive\Desktop\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...
